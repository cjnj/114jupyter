# %%
mylist = []
# mylist = list()

help (mylist)
# Out:
# Help on list object:
#
# class list(object)
#  |  list(iterable=(), /)
#  |
#  |  Built-in mutable sequence.
#  |
#  |  If no argument is given, the constructor creates a new empty list.
#  |  The argument must be an iterable if specified.
#  |
#  |  Methods defined here:
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __contains__(self, key, /)
#  |      Return key in self.
#  |
#  |  __delitem__(self, key, /)
#  |      Delete self[key].
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __getitem__(...)
#  |      x.__getitem__(y) <==> x[y]
#  |
#  |  __gt__(self, value, /)
#  |      Return self>value.
#  |
#  |  __iadd__(self, value, /)
#  |      Implement self+=value.
#  |
#  |  __imul__(self, value, /)
#  |      Implement self*=value.
#  |
#  |  __init__(self, /, *args, **kwargs)
# ...

# %%
# Printing an empty list :
print (mylist)

# Printing a list with exactly one element:
mylist = [1]
print(mylist)

# Printing a list with more than one element:
mylist.append(2)
print(mylist)
# Out:
# []
# [1]
# [1, 2]

# %%
# SinglylinkedList implementation

class SinglyLinkedList:
    def __init__(self):
        self.head = None

    class __Node:
        def __init__(self, data):
            self.data = data
            self.next = None

    def __str__(self):
        return ""

    def append(self, value):
        new_node = Node(data)
        if self.head is None:
            self.head = new_node

    def insert(self, index, value):
        new_node. = self.__Node(value)
        if not self.head:
            self.head = new_node
        else:
            count = 0
            current = self.head
            prev = None
            if index == count:
                old_head = sel.head
                self.head = new_node
                new_node.next = old_head
            else:
                while current.next and count != index:
                    prev = current
                    current = current.next
                    count += 1
                if count == index:
                    prev.next = new_node
                    new_node.next = current
                else:
                    current.next = new_node

    def remove(self, value):
        element = self.__Node(value)
        current_node = self.head
        while curent_node.next is not None:
            if(current_node.data == element):
                current_node.
    

    def index(self, index, value):
        pass

# %%
class SinglyLinkedList:
    def __init_(self, data):
        self.data = data
        self.next = None

# %%
# Consider the answer to the question: What have you tried?

# %%
new_list = [1,3]
# when the list is emptied the index doesn't matter
new_list.insert(100,0)

# this example is equivalent to an append
print(new_list)

# Here's an example of me replacing the head of the list:
new_list.insert(0,-1)
print(new_list)

# Her's an example of us adding a new node between 0 and _1
new_list.insert(1, -0.5)

print(new_list)

# What happens when the index os equal to or exceeds the length of the list:
new_list.insert(3, 1)

print(new_list)
# Out:
# [1, 3, 0]
# [-1, 1, 3, 0]
# [-1, -0.5, 1, 3, 0]
# [-1, -0.5, 1, 1, 3, 0]

# %%
# doubly linked lists

class DoublyLinkedList:
    def __init__(self):
        self.head = None

    class __Node:
        def __init__(self, data):
            self.data = data
            self.next = None
            self.prev = None

    def append(self, value):
        new_node = self.head:
        self.head = new_node
    else:
        current = self.head
        while current.next:
            current = current.next
            current.next = new_node
            new_node.prev = current
